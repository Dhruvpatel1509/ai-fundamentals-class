# %%
from dotenv import load_dotenv
import os

load_dotenv()  # ← add this

if os.environ.get("GROQ_API_KEY"):
    print("Groq API key is set")
if os.environ.get("GEMINI_API_KEY"):
    print("Google API key is set")
# Out:
# Groq API key is set
# Google API key is set

# %%
import os

from groq import Groq

client = Groq(
    api_key=os.environ.get("GROQ_API_KEY"),
)

chat_completion = client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": "Explain the importance of fast language models",
        }
    ],
    model="llama-3.3-70b-versatile",
)

print(chat_completion.choices[0].message.content)
# Out:
# Fast language models are crucial in various applications, and their importance can be understood from several perspectives:
#
# 1. **Real-time Processing**: Fast language models enable real-time processing of text-based input, which is essential for applications such as:
# 	* Chatbots and conversational AI: Quick responses are necessary to maintain engaging and interactive conversations.
# 	* Sentiment analysis: Fast processing of text helps to analyze user feedback and sentiment in real-time.
# 	* Live language translation: Rapid language models facilitate simultaneous translation, enabling efficient communication across languages.
# 2. **Improved User Experience**: Fast language models enhance the user experience in various ways:
# 	* Quick response times: Faster models reduce latency, resulting in more responsive and interactive systems.
# 	* Increased accuracy: Fast models can process more data, leading to improved accuracy and better decision-making.
# 	* Enhanced personalization: Rapid language models can analyze user preferences and adapt to their needs in real-time.
# 3. **Scalability and Efficiency**: Fast language models are essential for large-scale applications, as they:
# 	* Reduce computational resources: Faster models require less computational power, making them more efficient and cost-effective.
# 	* Increase throughput: Quick models can process more data in parallel, enabling larger volumes of text to be analyzed and generated.
# 	* Support distributed architectures: Fast language models can be easily integrated into distributed systems, facilitating scalability and reliability.
# 4. **Competitive Advantage**: In industries such as customer service, market research, and content creation, fast language models can provide a competitive advantage by:
# 	* Enabling rapid analysis of large datasets: Fast models can quickly analyze customer feedback, sentiment, and preferences, allowing businesses to respond promptly.
# 	* Automating content generation: Rapid language models can generate high-quality content, such as articles, social media posts, and product descriptions, at scale and speed.
# 	* Facilitating real-time decision-making: Fast language models can analyze market trends, news, and social media to inform business decisions and stay ahead of the competition.
# 5. **Research and Development**: Fast language models are vital for research and development, as they:
# 	* Enable rapid experimentation: Fast models facilitate the testing of new ideas, hypotheses, and architectures, accelerating the research process.
# 	* Support large-scale simulations: Quick models can simulate complex systems, such as language evolution, conversation dynamics, and social networks.
# 	* Drive innovation: Fast language models can be used to develop new applications, such as language-based interfaces, virtual assistants, and human-computer interaction systems.
#
# In summary, fast language models are essential for various applications, including real-time processing, improved user experience, scalability and efficiency, competitive advantage, and research and development. As the demand for language-based technologies continues to grow, the importance of fast language models will only increase.
