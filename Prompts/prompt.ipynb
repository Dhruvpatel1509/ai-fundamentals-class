# %%
from dotenv import load_dotenv
load_dotenv()
from langchain_groq import ChatGroq                          # replaces ChatOpenAI


llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
llm.invoke("Translate the following English sentence to French: 'How are you?'")
# Out:
# AIMessage(content="The translation of 'How are you?' in French is 'Comment allez-vous?' (formal) or 'Comment vas-tu?' (informal).", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 48, 'total_tokens': 81, 'completion_time': 0.075203903, 'completion_tokens_details': None, 'prompt_time': 0.002136826, 'prompt_tokens_details': None, 'queue_time': 0.047655742, 'total_time': 0.077340729}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_ba38bbab80', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019e1805-2114-7e91-b56c-f38e53e903b2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 48, 'output_tokens': 33, 'total_tokens': 81})
